# %%
a = 'abc'
if a == 'abc':
    print('abc')
# Out:
# abc

# %%
import torch
import numpy as np
from processor.io import IO
from processor.processor import Processor
from net.st_gcn import Model
from torchsummary import summary

# %%
# !pip install torchsummary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import torchlight
from torchlight import str2bool
from torchlight import DictAction
from torchlight import import_class

# %%
import torch
import torch.nn as nn
from net.st_gcn_alone import alone
from torchsummary import summary

# %%
model2_5 = alone(base_model='net.st_gcn.Model', output_class=7, in_channels=3, num_class=32, edge_importance_weighting=True, graph_args={'layout':'ntu-rgb+d', 'strategy':'spatial'})
model2_5.load_state_dict(torch.load('radar/ch128/2.5s/1114_86.49068322981367_epoch377_model.pt'))
model2_5.cuda()
model2_5.eval()
# Out:
# 75
# alone(
#   (rad_stgcn): Model(
#     (data_bn): BatchNorm1d(75, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (st_gcn_networks): ModuleList(
#       (0): st_gcn(
#         (gcn): ConvTemporalGraphical(
#           (conv): Conv2d(3, 384, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (tcn): Sequential(
#           (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#           (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): Dropout(p=0, inplace=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (1): st_gcn(
#         (gcn): ConvTemporalGraphical(
#           (conv): Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (tcn): Sequential(
# ...

# %%
summary(model2_5, (3, 50, 25), batch_size=13)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#        BatchNorm1d-1               [13, 75, 50]             150
#             Conv2d-2          [13, 384, 50, 25]           1,536
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 summary(model2_5, (3, 50, 25), batch_size=13)
#
# File ~/.local/lib/python3.10/site-packages/torchsummary/torchsummary.py:93, in summary(model, input_size, batch_size, device)
#      87 line_new = "{:>20}  {:>25} {:>15}".format(
#      88     layer,
#      89     str(summary[layer]["output_shape"]),
#      90     "{0:,}".format(summary[layer]["nb_params"]),
#      91 )
#      92 total_params += summary[layer]["nb_params"]
# ---> 93 total_output += np.prod(summary[layer]["output_shape"])
#      94 if "trainable" in summary[layer]:
# ...

# %%
model5 = alone(base_model='net.st_gcn.Model', output_class=7, in_channels=3, num_class=32, edge_importance_weighting=True, graph_args={'layout':'ntu-rgb+d', 'strategy':'spatial'})
model5.load_state_dict(torch.load('radar/ch128/5s/580_90.06211180124224_epoch566_model.pt'))
model5.cuda()
model5.eval()
# Out:
# 75
# alone(
#   (rad_stgcn): Model(
#     (data_bn): BatchNorm1d(75, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (st_gcn_networks): ModuleList(
#       (0): st_gcn(
#         (gcn): ConvTemporalGraphical(
#           (conv): Conv2d(3, 384, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (tcn): Sequential(
#           (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): Conv2d(128, 128, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#           (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): Dropout(p=0, inplace=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (1): st_gcn(
#         (gcn): ConvTemporalGraphical(
#           (conv): Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (tcn): Sequential(
# ...

# %%
#summary(model5, (3, 400, 25), batch_size=13)

l = [module for module in model5.modules() if not isinstance(module, nn.Sequential)]
l
#400 200 100 50
# Out:
# [alone(
#    (rad_stgcn): Model(
#      (data_bn): BatchNorm1d(75, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (st_gcn_networks): ModuleList(
#        (0): st_gcn(
#          (gcn): ConvTemporalGraphical(
#            (conv): Conv2d(3, 384, kernel_size=(1, 1), stride=(1, 1))
#          )
#          (tcn): Sequential(
#            (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (1): ReLU(inplace=True)
#            (2): Conv2d(128, 128, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#            (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (4): Dropout(p=0, inplace=True)
#          )
#          (relu): ReLU(inplace=True)
#        )
#        (1): st_gcn(
#          (gcn): ConvTemporalGraphical(
#            (conv): Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1))
#          )
#          (tcn): Sequential(
# ...
